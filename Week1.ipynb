# %% [markdown]
# <a href="https://colab.research.google.com/github/VozSoldat/PCVK-Ganjil-2025/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Langkah 1
# >Instalasi libray
#
# numpy, pandas, cv2, skimage, PIL, matplotlib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Langkah 2
# > membaca dan menampilkan image

# %%
imageUrls =  [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://preview.redd.it/does-anyone-know-the-breed-of-this-social-media-famous-cat-v0-ej4zxe2qxvld1.jpg?width=1080&crop=smart&auto=webp&s=7e7c70612b8a9a473706cf3b755ef776591ffcd9"]


for url in imageUrls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  # final_frame = cv.hconcat((image_2, image))

  # cv2_imshow(image)
  # cv2_imshow(image_2)
  cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=1080x882>

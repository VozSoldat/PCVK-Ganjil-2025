# %% [markdown]
# <a href="https://colab.research.google.com/github/VozSoldat/PCVK-Ganjil-2025/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jobsheet II (D3)

# %% [markdown]
# ## Buat koneksi ke Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive/MyDrive/PCVK/KTM.jpeg')

import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('KTM.jpeg')
cv2_imshow(img)

print("resolusi gambar:", img.shape[1], "x", img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=1410x868>
# resolusi gambar: 1410 x 868

# %% [markdown]
# ## Menampilkan Gambar (format BGR)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %% [markdown]
# ### Menampilkan format RGB

# %%
img = cv2.imread('KTM.jpeg', 1)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.show()

# %% [markdown]
# ## Menampilkan Citra Grayscale

# %%
img_gray = cv2.imread('KTM.jpeg', cv2.IMREAD_GRAYSCALE)

# Tanpa cmap
plt.subplot(1, 2, 1)
plt.imshow(img_gray)
plt.title('Tanpa cmap')

# Dengan cmap
plt.subplot(1, 2, 2)
plt.imshow(img_gray, cmap='gray')
plt.title('Dengan cmap')

plt.show()

# %% [markdown]
# ## Melakukan Resizing

# %%
img = cv2.imread('KTM.jpeg')
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # konversi BGR ke RGB
imgRGBsmall = cv2.resize(imgRGB, (400, 250)) # resize gambar
plt.imshow(imgRGBsmall)
# plt.show()

# %% [markdown]
# ## Melakukan Flipping

# %%
imgBalik = cv2.flip(imgRGBsmall, 1) # flip gambar
plt.imshow(imgBalik)

# %% [markdown]
# ### Perbesar ukuran canvas

# %%
imgBalik = cv2.flip(imgRGBsmall, 1) # flip gambar
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(imgBalik)

# %% [markdown]
# ## Membuat bentuk Geometri 2D dari OpenCV
# Mulai dengan black image dengan tipe data `int16`.

# %%
import numpy as np

black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# ### Menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv2.rectangle(black_img, pt1=(340, 0), pt2=(510, 150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Lanjut dengan kotak pada koordinat lain.

# %%
cv2.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Lanjut dengan lingkaran pada koordinat selanjutnya.

# %%
cv2.circle(black_img, center=(100, 100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Tambahkan garis diagonal.

# %%
cv2.line(black_img, pt1=(0,0), pt2=(511,511), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Tambahkan font (teks).

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=2, lineType=cv2.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# ### Pembuatan black image lagi

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# #### Reshape array tersebut

# %%
pts = vertices.reshape((-1, 1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# #### Penambahan polyline pada black image kedua

# %%
black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int16)
cv2.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)
plt.imshow(black_img2)
